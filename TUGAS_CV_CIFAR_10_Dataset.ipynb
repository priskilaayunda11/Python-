# %% [markdown]
# # Nama : Priskila Ayunda Pramata
#
# # Kelas : Alan Turing

# %% [markdown]
# # Import Library

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
from __future__ import print_function
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.regularizers import l2
import numpy as np
import os
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus'] = False
plt.style.use('fivethirtyeight')
# %matplotlib inline

# Defining the parameters
batch_size = 32
num_classes = 10
epochs = 25

# %% [markdown]
# # Importing CIFAR 10

# %%
# Splitting the data between train and test
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# #VISUALIZATION

# %%
# plotting some random 10 images

class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

fig = plt.figure(figsize=(10,5))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(y_train[:]==i)[0]
    features_idx = x_train[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = (features_idx[img_num,::])
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# # PRE-PROCESSING

# %%
# Convert class vectors to binary class matrices.
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# # DESIGNING CNN

# %%
# Building the CNN Model (Hidden Output)

model = Sequential()
model.add(Conv2D(64, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512,kernel_regularizer=l2(0.01)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %% [markdown]
# # VISUALIZATION CNN

# %%
pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.14-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (992 kB)
#      |████████████████████████████████| 992 kB 5.0 MB/s
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.14 visualkeras-0.0.2

# %%
# Visualizing our model (Hidden Input)
import visualkeras
visualkeras.layered_view(model, scale_xy=10, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=1201x463 at 0x7F3ACE25C390>

# %%
# Summary CNN
# summary of the model (Hidden Input)
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  activation (Activation)     (None, 32, 32, 64)        0
#
#  batch_normalization (BatchN  (None, 32, 32, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 64)        36928
#
#  activation_1 (Activation)   (None, 30, 30, 64)        0
#
#  batch_normalization_1 (Batc  (None, 30, 30, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 64)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 128)       73856
#
#  activation_2 (Activation)   (None, 15, 15, 128)       0
#
#  batch_normalization_2 (Batc  (None, 15, 15, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 128)       147584
#
#  activation_3 (Activation)   (None, 13, 13, 128)       0
#
#  batch_normalization_3 (Batc  (None, 13, 13, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 128)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 512)               2359808
#
#  activation_4 (Activation)   (None, 512)               0
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
#  activation_5 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 2,626,634
# Trainable params: 2,625,866
# Non-trainable params: 768
# _________________________________________________________________
# None

# %% [markdown]
# #Compiling & Training The Model:

# %%
# compile (Hidden Output)
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalizing the input image
x_train /= 255
x_test /= 255

epochs=25

# Training the model
history = model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
# Out:
# Epoch 1/25
# 1563/1563 [==============================] - 45s 22ms/step - loss: 8.5443 - accuracy: 0.4197 - val_loss: 6.3475 - val_accuracy: 0.5289
# Epoch 2/25
# 1563/1563 [==============================] - 32s 20ms/step - loss: 4.9787 - accuracy: 0.5607 - val_loss: 3.7156 - val_accuracy: 0.6494
# Epoch 3/25
# 1563/1563 [==============================] - 32s 20ms/step - loss: 3.0916 - accuracy: 0.6391 - val_loss: 2.4905 - val_accuracy: 0.6678
# Epoch 4/25
# 1563/1563 [==============================] - 31s 20ms/step - loss: 2.0783 - accuracy: 0.6885 - val_loss: 1.6978 - val_accuracy: 0.7263
# Epoch 5/25
# 1563/1563 [==============================] - 32s 20ms/step - loss: 1.5316 - accuracy: 0.7205 - val_loss: 1.3330 - val_accuracy: 0.7406
# Epoch 6/25
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.2283 - accuracy: 0.7437 - val_loss: 1.2166 - val_accuracy: 0.7240
# Epoch 7/25
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.0545 - accuracy: 0.7618 - val_loss: 1.0228 - val_accuracy: 0.7652
# Epoch 8/25
# 1563/1563 [==============================] - 32s 20ms/step - loss: 0.9584 - accuracy: 0.7776 - val_loss: 0.9405 - val_accuracy: 0.7748
# Epoch 9/25
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.8959 - accuracy: 0.7899 - val_loss: 0.9749 - val_accuracy: 0.7630
# Epoch 10/25
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.8581 - accuracy: 0.8028 - val_loss: 0.9992 - val_accuracy: 0.7578
# Epoch 11/25
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.8277 - accuracy: 0.8123 - val_loss: 0.9034 - val_accuracy: 0.7860
# Epoch 12/25
# 1563/1563 [==============================] - 32s 20ms/step - loss: 0.8111 - accuracy: 0.8217 - val_loss: 0.8909 - val_accuracy: 0.7966
# Epoch 13/25
# 1563/1563 [==============================] - 32s 20ms/step - loss: 0.7952 - accuracy: 0.8290 - val_loss: 0.8970 - val_accuracy: 0.7999
# Epoch 14/25
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.7859 - accuracy: 0.8378 - val_loss: 0.9295 - val_accuracy: 0.7928
# Epoch 15/25
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.7786 - accuracy: 0.8444 - val_loss: 0.9204 - val_accuracy: 0.8000
# Epoch 16/25
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.7752 - accuracy: 0.8478 - val_loss: 0.9011 - val_accuracy: 0.8145
# Epoch 17/25
# 1563/1563 [==============================] - 32s 20ms/step - loss: 0.7710 - accuracy: 0.8581 - val_loss: 1.0224 - val_accuracy: 0.7879
# Epoch 18/25
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.7758 - accuracy: 0.8607 - val_loss: 0.9255 - val_accuracy: 0.8149
# Epoch 19/25
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.7625 - accuracy: 0.8699 - val_loss: 0.9494 - val_accuracy: 0.8183
# Epoch 20/25
# 1563/1563 [==============================] - 32s 20ms/step - loss: 0.7638 - accuracy: 0.8730 - val_loss: 0.9779 - val_accuracy: 0.8144
# Epoch 21/25
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.7648 - accuracy: 0.8777 - val_loss: 0.9504 - val_accuracy: 0.8232
# Epoch 22/25
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.7670 - accuracy: 0.8779 - val_loss: 0.9679 - val_accuracy: 0.8262
# Epoch 23/25
# 1563/1563 [==============================] - 32s 20ms/step - loss: 0.7685 - accuracy: 0.8821 - val_loss: 0.9679 - val_accuracy: 0.8249
# Epoch 24/25
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.7674 - accuracy: 0.8850 - val_loss: 0.9978 - val_accuracy: 0.8182
# Epoch 25/25
# 1563/1563 [==============================] - 31s 20ms/step - loss: 0.7653 - accuracy: 0.8881 - val_loss: 0.9886 - val_accuracy: 0.8267

# %% [markdown]
# # Evaluasi Model

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.9886 - accuracy: 0.8267

# %%
# Plotting the Model Accuracy & Model Loss vs Epochs (Hidden Input)
plt.figure(figsize=[20,8])

# summarize history for accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy', size=25, pad=20)
plt.ylabel('Accuracy', size=15)
plt.xlabel('Epoch', size=15)
plt.legend(['train', 'test'], loc='upper left')
# summarize history for loss

plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss', size=25, pad=20)
plt.ylabel('Loss', size=15)
plt.xlabel('Epoch', size=15)
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Prediction dengan Model CNN

# %%
# Checking the predictions! (Hidden Input)
predictions = model.predict(x_test)

plt.figure(figsize=[10,10])

class_names = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

plt.subplot(2,2,1)
n = 3
plt.imshow(x_test[n].reshape(32, 32, -1), cmap=plt.cm.binary)
plt.title("Predicted value: " + str(class_names[np.argmax(predictions[n], axis=0)]), size=20)
plt.grid(False)

plt.subplot(2,2,2)
n = 4
plt.imshow(x_test[n].reshape(32, 32, -1), cmap=plt.cm.binary)
plt.title("Predicted value: " + str(class_names[np.argmax(predictions[n], axis=0)]), size=20)
plt.grid(False)

plt.subplot(2,2,3)
n = 8
plt.imshow(x_test[n].reshape(32, 32, -1), cmap=plt.cm.binary)
plt.title("Predicted value: " + str(class_names[np.argmax(predictions[n], axis=0)]), size=20)
plt.grid(False)

plt.subplot(2,2,4)
n = 6
plt.imshow(x_test[n].reshape(32, 32, -1), cmap=plt.cm.binary)
plt.title("Predicted value: " + str(class_names[np.argmax(predictions[n], axis=0)]), size=20)
plt.grid(False)

plt.suptitle("Predictions of CIFAR-10 Data", size=30, color="#6166B3")

plt.show()

# %% [markdown]
# # Menggunakan Optimizer Adam

# %%
model.compile(optimizer='adam', loss=tf.losses.CosineSimilarity(), metrics= ['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalizing the input image
x_train /= 255
x_test /= 255

history = model.fit(x_train, y_train, batch_size=5, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 36s 21ms/step - loss: 0.3302 - accuracy: 0.1962 - val_loss: 0.1905 - val_accuracy: 0.1075
# Epoch 2/10
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.2928 - accuracy: 0.1770 - val_loss: 0.3887 - val_accuracy: 0.1000
# Epoch 3/10
# 1563/1563 [==============================] - 32s 21ms/step - loss: 0.2753 - accuracy: 0.1782 - val_loss: 0.2765 - val_accuracy: 0.0999
# Epoch 4/10
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.3082 - accuracy: 0.1955 - val_loss: 0.7219 - val_accuracy: 0.1000
# Epoch 5/10
# 1563/1563 [==============================] - 32s 20ms/step - loss: 0.2649 - accuracy: 0.2093 - val_loss: 0.3879 - val_accuracy: 0.1015
# Epoch 6/10
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.2979 - accuracy: 0.2001 - val_loss: 0.3042 - val_accuracy: 0.1107
# Epoch 7/10
# 1563/1563 [==============================] - 32s 20ms/step - loss: 0.2285 - accuracy: 0.1910 - val_loss: 0.4117 - val_accuracy: 0.0996
# Epoch 8/10
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.2222 - accuracy: 0.2156 - val_loss: 0.4572 - val_accuracy: 0.1000
# Epoch 9/10
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.2006 - accuracy: 0.2222 - val_loss: 0.2887 - val_accuracy: 0.1000
# Epoch 10/10
# 1563/1563 [==============================] - 33s 21ms/step - loss: 0.2108 - accuracy: 0.2319 - val_loss: 0.4653 - val_accuracy: 0.1008

# %% [markdown]
# # Evaluasi Model

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4653 - accuracy: 0.1008

# %%
# Plotting the Model Accuracy & Model Loss vs Epochs (Hidden Input)
plt.figure(figsize=[20,8])

# summarize history for accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy', size=25, pad=20)
plt.ylabel('Accuracy', size=15)
plt.xlabel('Epoch', size=15)
plt.legend(['train', 'test'], loc='upper left')
# summarize history for loss

plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss', size=25, pad=20)
plt.ylabel('Loss', size=15)
plt.xlabel('Epoch', size=15)
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Prediksi dengan CNN

# %%
# Checking the predictions! (Hidden Input)
predictions = model.predict(x_test)

plt.figure(figsize=[10,10])

class_names = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

plt.subplot(2,2,1)
n = 3
plt.imshow(x_test[n].reshape(32, 32, -1), cmap=plt.cm.binary)
plt.title("Predicted value: " + str(class_names[np.argmax(predictions[n], axis=0)]), size=20)
plt.grid(False)

plt.subplot(2,2,2)
n = 4
plt.imshow(x_test[n].reshape(32, 32, -1), cmap=plt.cm.binary)
plt.title("Predicted value: " + str(class_names[np.argmax(predictions[n], axis=0)]), size=20)
plt.grid(False)

plt.subplot(2,2,3)
n = 8
plt.imshow(x_test[n].reshape(32, 32, -1), cmap=plt.cm.binary)
plt.title("Predicted value: " + str(class_names[np.argmax(predictions[n], axis=0)]), size=20)
plt.grid(False)

plt.subplot(2,2,4)
n = 6
plt.imshow(x_test[n].reshape(32, 32, -1), cmap=plt.cm.binary)
plt.title("Predicted value: " + str(class_names[np.argmax(predictions[n], axis=0)]), size=20)
plt.grid(False)

plt.suptitle("Predictions of CIFAR-10 Data", size=30, color="#6166B3")

plt.show()
